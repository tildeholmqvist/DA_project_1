# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# * Analyse online retail transaction data to understand customer behaviour, identify popular products, and optimise pricing and marketing strategies.
#
# ## Inputs
#
# * data/source/online_retail.csv
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/tildeholmqvist/Documents/VS_Code_Tilde/DA_project_1/DA_project_1/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/tildeholmqvist/Documents/VS_Code_Tilde/DA_project_1/DA_project_1'

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy==1.26.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: pandas==2.1.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: matplotlib==3.8.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (3.8.0)
# Requirement already satisfied: seaborn==0.13.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: ydata-profiling==4.12.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (4.12.0)
# Requirement already satisfied: plotly==5.17.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (5.17.0)
# Requirement already satisfied: streamlit==1.40.2 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.40.2)
# Requirement already satisfied: feature-engine==1.6.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (1.6.1)
# Requirement already satisfied: imbalanced-learn==0.11.0 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: scikit-learn==1.3.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: xgboost==1.7.6 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.7.6)
# Requirement already satisfied: yellowbrick==1.5 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.5)
# Requirement already satisfied: Pillow==10.0.1 in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (10.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas==2.1.1->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas==2.1.1->-r requirements.txt (line 2)) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.12/site-packages (from pandas==2.1.1->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.8.0->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.8.0->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.8.0->-r requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.8.0->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.8.0->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib==3.8.0->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (1.13.1)
# Requirement already satisfied: pydantic>=2 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (2.12.5)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in ./.venv/lib/python3.12/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: multimethod<2,>=1.4 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.14.6)
# Requirement already satisfied: typeguard<5,>=3 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (4.5.1)
# Requirement already satisfied: imagehash==4.3.1 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (1.9.6)
# Requirement already satisfied: dacite>=1.8 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (1.9.2)
# Requirement already satisfied: numba<1,>=0.56.0 in ./.venv/lib/python3.12/site-packages (from ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.64.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./.venv/lib/python3.12/site-packages (from plotly==5.17.0->-r requirements.txt (line 6)) (9.1.4)
# Requirement already satisfied: altair<6,>=4.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (8.3.1)
# Requirement already satisfied: protobuf<6,>=3.20 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (23.0.1)
# Requirement already satisfied: rich<14,>=10.14.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: toml<2,>=0.10.1 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.venv/lib/python3.12/site-packages (from streamlit==1.40.2->-r requirements.txt (line 7)) (6.5.5)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.12/site-packages (from imbalanced-learn==0.11.0->-r requirements.txt (line 9)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.12/site-packages (from imbalanced-learn==0.11.0->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: PyWavelets in ./.venv/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit==1.40.2->-r requirements.txt (line 7)) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in ./.venv/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit==1.40.2->-r requirements.txt (line 7)) (2.18.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.40.2->-r requirements.txt (line 7)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.40.2->-r requirements.txt (line 7)) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in ./.venv/lib/python3.12/site-packages (from numba<1,>=0.56.0->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.46.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit==1.40.2->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit==1.40.2->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in ./.venv/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in ./.venv/lib/python3.12/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.40.2->-r requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.40.2->-r requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.40.2->-r requirements.txt (line 7)) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.40.2->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==4.12.0->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.1.1->-r requirements.txt (line 2)) (1.17.0)

# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Section 1 - Load Data

# %% [markdown]
# In this section, we load the raw transaction data from the source CSV file and prepare it as a DataFrame for analysis.
#
# * Input: data/source/online_retail.csv
# * Output: A raw DataFrame (df_raw) containing all transactions

# %%
df = pd.read_csv("data/source/online_retail.csv")
print(df.shape)
# Out:
# (541909, 8)

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 - Missing Data

# %%
df.isna().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
